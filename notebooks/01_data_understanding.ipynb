# %% [markdown]
# # 01 Data Understanding
#
# Load the Telco churn dataset, inspect schema, and generate data-quality summaries.

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().resolve().parent if Path.cwd().name == 'notebooks' else Path.cwd().resolve()
sys.path.append(str(PROJECT_ROOT))

# %%
from src.data_loader import build_data_quality_summary, load_raw_data

df = load_raw_data()
df.shape

# %%
df.head()

# %%
summary = build_data_quality_summary(df)
summary['missing_values'].head(10)
