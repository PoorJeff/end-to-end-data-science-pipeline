# %% [markdown]
# # 02 Exploratory Data Analysis
#
# Generate visual analysis artifacts for churn distribution, numerical features, categorical churn rates, and correlations.

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().resolve().parent if Path.cwd().name == 'notebooks' else Path.cwd().resolve()
sys.path.append(str(PROJECT_ROOT))

# %%
from src.config import FIGURES_DIR
from src.data_loader import load_raw_data
from src.eda import save_eda_figures

df = load_raw_data()
save_eda_figures(df, FIGURES_DIR)
sorted(path.name for path in FIGURES_DIR.glob('*.png'))
